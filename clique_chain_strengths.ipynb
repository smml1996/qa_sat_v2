# %%
from utils import load_cnf, cnf_to_bqm
from embedding_utils import *
import seaborn as sns
from redundancy import *
from utils import *
from dwave.embedding.chain_strength import scaled
import pandas as pd
from brute_force import get_bqm_random_sat
import numpy as np
import matplotlib.pyplot as plt

# %%
seed = 1
qpu = get_qpu().to_networkx_graph()

# %%
def find_best_chain_strength(bqm, embedding, top_chain_strength, clauses, file_name):
    chain_strengths = []
    precisions = []
    for chain_strength in list(np.arange(1.0, top_chain_strength + 0.25, 0.25)):
        chain_strengths.append(chain_strength)
        precisions.append(sample_with_sampler(embedding, bqm, 100, chain_strength, clauses))
    current_df = pd.DataFrame({
     'chain_strength': chain_strengths,
     'precision': precisions,
     })  
    current_df.to_csv(f"./rnd_cnf_precision/clique_{file_name}.csv")
    return current_df

# %% [markdown]
# ## 10 variables

# %%
for n_clauses in [10,15, 20, 25]:
    bqm, clauses = get_bqm_random_sat(10, n_clauses, seed)
    embedding = get_clique_embedding(bqm, qpu, seed_=1)
    print(scaled(bqm, embedding), max(bqm.quadratic.values()) )
# Out:
# best embedding max_chain_length 3
# best embedding qubits used 60
# best embedding variance: 0
# 6.0 4.0
# best embedding max_chain_length 4
# best embedding qubits used 94
# best embedding variance: 0.19
# 8.0 4.0
# best embedding max_chain_length 4
# best embedding qubits used 114
# best embedding variance: 0.16551724137931034
# 8.0 4.0
# best embedding max_chain_length 5
# best embedding qubits used 168
# best embedding variance: 0.16470588235294117
# 16.0 4.0

# %%
# bqm, clauses = get_bqm_random_sat(10, 10, seed)
# embedding = get_clique_embedding(bqm, qpu, seed_=1)
# current_df = find_best_chain_strength(bqm, embedding, 6.0, clauses, "v10_c10")

# %%
df = pd.read_csv("./rnd_cnf_precision/clique_v10_c10.csv")
plt.axvline(4, 0,1.0,color='r')
sns.lineplot(data=df, x="chain_strength", y="precision")
# Out:
# <AxesSubplot:xlabel='chain_strength', ylabel='precision'>

# %%
# bqm, clauses = get_bqm_random_sat(10, 15, seed)
# embedding = get_clique_embedding(bqm, qpu, seed_=1)
# current_df = find_best_chain_strength(bqm, embedding, 5.0, clauses, "v10_c15")

# %%
df = pd.read_csv("./rnd_cnf_precision/clique_v10_c15.csv")
plt.axvline(4, 0,1.0,color='r')
sns.lineplot(data=df, x="chain_strength", y="precision")
# Out:
# <AxesSubplot:xlabel='chain_strength', ylabel='precision'>

# %%
# bqm, clauses = get_bqm_random_sat(10, 20, seed)
# embedding = get_clique_embedding(bqm, qpu, seed_=1)
# current_df = find_best_chain_strength(bqm, embedding, 5.0, clauses, "v10_c20")

# %%
df = pd.read_csv("./rnd_cnf_precision/clique_v10_c20.csv")
plt.axvline(4, 0,1.0,color='r')
sns.lineplot(data=df, x="chain_strength", y="precision")
# Out:
# <AxesSubplot:xlabel='chain_strength', ylabel='precision'>

# %%
# bqm, clauses = get_bqm_random_sat(10, 25, seed)
# embedding = get_clique_embedding(bqm, qpu, seed_=1)
# current_df = find_best_chain_strength(bqm, embedding, 5.0, clauses, "v10_c25")

# %%
df = pd.read_csv("./rnd_cnf_precision/clique_v10_c25.csv")
plt.axvline(4, 0,1.0,color='r')
sns.lineplot(data=df, x="chain_strength", y="precision")
# Out:
# <AxesSubplot:xlabel='chain_strength', ylabel='precision'>

# %% [markdown]
# ## 15 variables

# %%
for n_clauses in [15, 20, 25, 30, 35, 40, 45]:
    bqm, clauses = get_bqm_random_sat(15, n_clauses, seed)
    embedding = get_clique_embedding(bqm, qpu, seed_=1)
    print(scaled(bqm, embedding), max(bqm.quadratic.values()) )
# Out:
# best embedding max_chain_length 4
# best embedding qubits used 114
# best embedding variance: 0.16551724137931034
# 12.0 4.0
# best embedding max_chain_length 5
# best embedding qubits used 168
# best embedding variance: 0.16470588235294117
# 12.0 4.0
# best embedding max_chain_length 5
# best embedding qubits used 192
# best embedding variance: 0.1641025641025641
# 12.0 4.0
# best embedding max_chain_length 6
# best embedding qubits used 260
# best embedding variance: 0.17676767676767677
# 16.0 4.0
# best embedding max_chain_length 6
# best embedding qubits used 290
# best embedding variance: 0.16326530612244897
# 18.0 6.0
# best embedding max_chain_length 7
# best embedding qubits used 375
# best embedding variance: 0.1515151515151515
# 20.0 6.0
# best embedding max_chain_length 7
# best embedding qubits used 408
# best embedding variance: 0.16271186440677965
# 20.0 6.0

# %%
# bqm, clauses = get_bqm_random_sat(15, 15, seed)
# embedding = get_clique_embedding(bqm, qpu, seed_=1)
# current_df = find_best_chain_strength(bqm, embedding, 5.0, clauses, "v15_c15")

# %%
df = pd.read_csv("./rnd_cnf_precision/clique_v15_c15.csv")
plt.axvline(4, 0,1.0,color='r')
sns.lineplot(data=df, x="chain_strength", y="precision")
# Out:
# <AxesSubplot:xlabel='chain_strength', ylabel='precision'>

# %%
# bqm, clauses = get_bqm_random_sat(15, 20, seed)
# embedding = get_clique_embedding(bqm, qpu, seed_=1)
# current_df = find_best_chain_strength(bqm, embedding, 5.0, clauses, "v15_c20")

# %%
df = pd.read_csv("./rnd_cnf_precision/clique_v15_c20.csv")
plt.axvline(4, 0,1.0,color='r')
sns.lineplot(data=df, x="chain_strength", y="precision")
# Out:
# <AxesSubplot:xlabel='chain_strength', ylabel='precision'>

# %%
# bqm, clauses = get_bqm_random_sat(15, 25, seed)
# embedding = get_clique_embedding(bqm, qpu, seed_=1)
# current_df = find_best_chain_strength(bqm, embedding, 5.0, clauses, "v15_c25")

# %%
df = pd.read_csv("./rnd_cnf_precision/clique_v15_c25.csv")
plt.axvline(4, 0,1.0,color='r')
sns.lineplot(data=df, x="chain_strength", y="precision")
# Out:
# <AxesSubplot:xlabel='chain_strength', ylabel='precision'>

# %%
# bqm, clauses = get_bqm_random_sat(15, 30, seed)
# embedding = get_clique_embedding(bqm, qpu, seed_=1)
# current_df = find_best_chain_strength(bqm, embedding, 5.0, clauses, "v15_c30")

# %%
df = pd.read_csv("./rnd_cnf_precision/clique_v15_c30.csv")
plt.axvline(4, 0,1.0,color='r')
sns.lineplot(data=df, x="chain_strength", y="precision")
# Out:
# <AxesSubplot:xlabel='chain_strength', ylabel='precision'>

# %%
bqm, clauses = get_bqm_random_sat(15, 35, seed)
embedding = get_clique_embedding(bqm, qpu, seed_=1)
current_df = find_best_chain_strength(bqm, embedding, 7.0, clauses, "v15_c35")
# Out:
# best embedding max_chain_length 6
# best embedding qubits used 290
# best embedding variance: 0.16326530612244897
# lowest energy achieved: 4.0
# ground energy samples 0/100
# lowest energy achieved: 2.0
# ground energy samples 0/100
# lowest energy achieved: 2.0
# ground energy samples 0/100
# lowest energy achieved: 2.0
# ground energy samples 0/100
# lowest energy achieved: 0.0
# ground energy samples 2/100
# lowest energy achieved: 0.0
# ground energy samples 1/100
# lowest energy achieved: 3.0
# ground energy samples 0/100
# lowest energy achieved: 2.0
# ground energy samples 0/100
# lowest energy achieved: 4.0
# ground energy samples 0/100
# lowest energy achieved: 4.0
# ground energy samples 0/100
# lowest energy achieved: 6.0
# ground energy samples 0/100
# lowest energy achieved: 6.0
# ground energy samples 0/100
# lowest energy achieved: 6.0
# ground energy samples 0/100
# lowest energy achieved: 6.0
# ground energy samples 0/100
# lowest energy achieved: 6.0
# ground energy samples 0/100
# lowest energy achieved: 10.0
# ground energy samples 0/100
# lowest energy achieved: 8.0
# ground energy samples 0/100
# lowest energy achieved: 10.0
# ground energy samples 0/100
# lowest energy achieved: 6.0
# ground energy samples 0/100
# lowest energy achieved: 9.0
# ground energy samples 0/100
# lowest energy achieved: 11.0
# ground energy samples 0/100
# lowest energy achieved: 10.0
# ground energy samples 0/100
# lowest energy achieved: 10.0
# ground energy samples 0/100
# lowest energy achieved: 17.0
# ground energy samples 0/100
# lowest energy achieved: 12.0
# ground energy samples 0/100

# %%
df = pd.read_csv("./rnd_cnf_precision/clique_v15_c35.csv")
plt.axvline(6, 0,1.0,color='r')
sns.lineplot(data=df, x="chain_strength", y="precision")
# Out:
# <AxesSubplot:xlabel='chain_strength', ylabel='precision'>

# %%
bqm, clauses = get_bqm_random_sat(15, 40, seed)
embedding = get_clique_embedding(bqm, qpu, seed_=1)
current_df = find_best_chain_strength(bqm, embedding, 7.0, clauses, "v15_c40")
# Out:
# best embedding max_chain_length 7
# best embedding qubits used 375
# best embedding variance: 0.1515151515151515
# lowest energy achieved: 3.0
# ground energy samples 0/100
# lowest energy achieved: 2.0
# ground energy samples 0/100
# lowest energy achieved: 0.0
# ground energy samples 1/100
# lowest energy achieved: 0.0
# ground energy samples 1/100
# lowest energy achieved: 0.0
# ground energy samples 2/100
# lowest energy achieved: 0.0
# ground energy samples 1/100
# lowest energy achieved: 3.0
# ground energy samples 0/100
# lowest energy achieved: 4.0
# ground energy samples 0/100
# lowest energy achieved: 1.0
# ground energy samples 0/100
# lowest energy achieved: 6.0
# ground energy samples 0/100
# lowest energy achieved: 4.0
# ground energy samples 0/100
# lowest energy achieved: 5.0
# ground energy samples 0/100
# lowest energy achieved: 9.0
# ground energy samples 0/100
# lowest energy achieved: 9.0
# ground energy samples 0/100
# lowest energy achieved: 8.0
# ground energy samples 0/100
# lowest energy achieved: 13.0
# ground energy samples 0/100
# lowest energy achieved: 15.0
# ground energy samples 0/100
# lowest energy achieved: 15.0
# ground energy samples 0/100
# lowest energy achieved: 12.0
# ground energy samples 0/100
# lowest energy achieved: 4.0
# ground energy samples 0/100
# lowest energy achieved: 13.0
# ground energy samples 0/100
# lowest energy achieved: 14.0
# ground energy samples 0/100
# lowest energy achieved: 15.0
# ground energy samples 0/100
# lowest energy achieved: 20.0
# ground energy samples 0/100
# lowest energy achieved: 14.0
# ground energy samples 0/100

# %%
df = pd.read_csv("./rnd_cnf_precision/clique_v15_c40.csv")
plt.axvline(6, 0,1.0,color='r')
sns.lineplot(data=df, x="chain_strength", y="precision")
# Out:
# <AxesSubplot:xlabel='chain_strength', ylabel='precision'>

# %%
bqm, clauses = get_bqm_random_sat(15, 45, seed)
embedding = get_clique_embedding(bqm, qpu, seed_=1)
current_df = find_best_chain_strength(bqm, embedding, 7.0, clauses, "v15_c45")
# Out:
# best embedding max_chain_length 7
# best embedding qubits used 408
# best embedding variance: 0.16271186440677965
# lowest energy achieved: 6.0
# ground energy samples 0/100
# lowest energy achieved: 3.0
# ground energy samples 0/100
# lowest energy achieved: 3.0
# ground energy samples 0/100
# lowest energy achieved: 2.0
# ground energy samples 0/100
# lowest energy achieved: 3.0
# ground energy samples 0/100
# lowest energy achieved: 2.0
# ground energy samples 0/100
# lowest energy achieved: 4.0
# ground energy samples 0/100
# lowest energy achieved: 6.0
# ground energy samples 0/100
# lowest energy achieved: 4.0
# ground energy samples 0/100
# lowest energy achieved: 9.0
# ground energy samples 0/100
# lowest energy achieved: 2.0
# ground energy samples 0/100
# lowest energy achieved: 8.0
# ground energy samples 0/100
# lowest energy achieved: 13.0
# ground energy samples 0/100
# lowest energy achieved: 14.0
# ground energy samples 0/100
# lowest energy achieved: 13.0
# ground energy samples 0/100
# lowest energy achieved: 5.0
# ground energy samples 0/100
# lowest energy achieved: 17.0
# ground energy samples 0/100
# lowest energy achieved: 17.0
# ground energy samples 0/100
# lowest energy achieved: 15.0
# ground energy samples 0/100
# lowest energy achieved: 17.0
# ground energy samples 0/100
# lowest energy achieved: 17.0
# ground energy samples 0/100
# lowest energy achieved: 18.0
# ground energy samples 0/100
# lowest energy achieved: 20.0
# ground energy samples 0/100
# lowest energy achieved: 20.0
# ground energy samples 0/100
# lowest energy achieved: 19.0
# ground energy samples 0/100

# %%
df = pd.read_csv("./rnd_cnf_precision/clique_v15_c45.csv")
plt.axvline(6, 0,1.0,color='r')
sns.lineplot(data=df, x="chain_strength", y="precision")
# Out:
# <AxesSubplot:xlabel='chain_strength', ylabel='precision'>

# %% [markdown]
# ## 20 variables

# %%
for n_clauses in [30, 35]:
    bqm, clauses = get_bqm_random_sat(20, n_clauses, seed)
    embedding = get_clique_embedding(bqm, qpu, seed_=1)
#     temp = []
#     for val in bqm.quadratic.values():
#         temp.append(abs(val))
#     print(max(temp))
    print(scaled(bqm, embedding), max(bqm.quadratic.values()) )
# Out:
# best embedding max_chain_length 6
# best embedding qubits used 290
# best embedding variance: 0.16326530612244897
# 12.0 5.0
# best embedding max_chain_length 7
# best embedding qubits used 375
# best embedding variance: 0.1515151515151515
# 14.0 5.0

# %%
bqm, clauses = get_bqm_random_sat(20, 30, seed)
embedding = get_clique_embedding(bqm, qpu, seed_=1)
current_df = find_best_chain_strength(bqm, embedding, 6.0, clauses, "v20_c30")
# Out:
# best embedding max_chain_length 6
# best embedding qubits used 290
# best embedding variance: 0.16326530612244897
# lowest energy achieved: 1.0
# ground energy samples 0/100
# lowest energy achieved: 0.0
# ground energy samples 1/100
# lowest energy achieved: 0.0
# ground energy samples 8/100
# lowest energy achieved: 0.0
# ground energy samples 6/100
# lowest energy achieved: 0.0
# ground energy samples 6/100
# lowest energy achieved: 0.0
# ground energy samples 8/100
# lowest energy achieved: 1.0
# ground energy samples 0/100
# lowest energy achieved: 2.0
# ground energy samples 0/100
# lowest energy achieved: 0.0
# ground energy samples 1/100
# lowest energy achieved: 4.0
# ground energy samples 0/100
# lowest energy achieved: 2.0
# ground energy samples 0/100
# lowest energy achieved: 4.0
# ground energy samples 0/100
# lowest energy achieved: 5.0
# ground energy samples 0/100
# lowest energy achieved: 3.0
# ground energy samples 0/100
# lowest energy achieved: 3.0
# ground energy samples 0/100
# lowest energy achieved: 4.0
# ground energy samples 0/100
# lowest energy achieved: 6.0
# ground energy samples 0/100
# lowest energy achieved: 6.0
# ground energy samples 0/100
# lowest energy achieved: 8.0
# ground energy samples 0/100
# lowest energy achieved: 7.0
# ground energy samples 0/100
# lowest energy achieved: 10.0
# ground energy samples 0/100

# %%
df = pd.read_csv("./rnd_cnf_precision/clique_v20_c30.csv")
plt.axvline(5, 0,1.0,color='r')
sns.lineplot(data=df, x="chain_strength", y="precision")
# Out:
# <AxesSubplot:xlabel='chain_strength', ylabel='precision'>

# %%
bqm, clauses = get_bqm_random_sat(20, 35, seed)
embedding = get_clique_embedding(bqm, qpu, seed_=1)
current_df = find_best_chain_strength(bqm, embedding, 6.0, clauses, "v20_c35")
# Out:
# best embedding max_chain_length 7
# best embedding qubits used 375
# best embedding variance: 0.1515151515151515
# lowest energy achieved: 4.0
# ground energy samples 0/100
# lowest energy achieved: 0.0
# ground energy samples 2/100
# lowest energy achieved: 1.0
# ground energy samples 0/100
# lowest energy achieved: 0.0
# ground energy samples 1/100
# lowest energy achieved: 1.0
# ground energy samples 0/100
# lowest energy achieved: 0.0
# ground energy samples 1/100
# lowest energy achieved: 1.0
# ground energy samples 0/100
# lowest energy achieved: 2.0
# ground energy samples 0/100
# lowest energy achieved: 4.0
# ground energy samples 0/100
# lowest energy achieved: 5.0
# ground energy samples 0/100
# lowest energy achieved: 6.0
# ground energy samples 0/100
# lowest energy achieved: 6.0
# ground energy samples 0/100
# lowest energy achieved: 8.0
# ground energy samples 0/100
# lowest energy achieved: 6.0
# ground energy samples 0/100
# lowest energy achieved: 8.0
# ground energy samples 0/100
# lowest energy achieved: 10.0
# ground energy samples 0/100
# lowest energy achieved: 12.0
# ground energy samples 0/100
# lowest energy achieved: 10.0
# ground energy samples 0/100
# lowest energy achieved: 12.0
# ground energy samples 0/100
# lowest energy achieved: 11.0
# ground energy samples 0/100
# lowest energy achieved: 12.0
# ground energy samples 0/100

# %%
df = pd.read_csv("./rnd_cnf_precision/clique_v20_c35.csv")
plt.axvline(5, 0,1.0,color='r')
sns.lineplot(data=df, x="chain_strength", y="precision")
# Out:
# <AxesSubplot:xlabel='chain_strength', ylabel='precision'>

# %% [markdown]
# # Merging Results

# %%
def get_best_results():
    vars_to_clauses = {
        10: [10, 15, 20, 25],
        15: [15, 20, 25, 30, 35, 40, 45],
        20: [30, 35]
    }

    total_rows = 0
    nvars_series = []
    nclauses_series = []
    chain_strengths = []
    precisions = []
    coeffs = []
    for (n_vars, n_clauses_arr) in vars_to_clauses.items():
        for n_clauses in n_clauses_arr:
            current_df = pd.read_csv(f"./rnd_cnf_precision/clique_v{n_vars}_c{n_clauses}.csv")[["chain_strength", "precision"]]
            best_chain_strength = current_df.loc[current_df['precision'].idxmax()]['chain_strength']
            best_precision = current_df.loc[current_df['precision'].idxmax()]['precision']
            bqm, clauses = get_bqm_random_sat(n_vars, n_clauses, seed)
            nvars_series.append(n_vars)
            nclauses_series.append(n_clauses)
            chain_strengths.append(best_chain_strength)
            precisions.append(best_precision)
            coeffs.append(max(bqm.quadratic.values()))
            
    df = pd.DataFrame({
        'vars': nvars_series,
        'clauses': nclauses_series,
        'chain_strength':chain_strengths,
        'precision': precisions,
        'max_coeff': coeffs
    })
    return df

# %%
df_chain_strengths = get_best_results()
df_chain_strengths
# Out:
#     vars  clauses  chain_strength  precision  max_coeff
# 0     10       10            1.50       0.51        4.0
# 1     10       15            1.75       0.21        4.0
# 2     10       20            1.75       0.21        4.0
# 3     10       25            1.75       0.07        4.0
# 4     15       15            1.75       0.35        4.0
# 5     15       20            2.00       0.17        4.0
# 6     15       25            1.75       0.10        4.0
# 7     15       30            1.50       0.06        4.0
# 8     15       35            2.00       0.02        6.0
# 9     15       40            2.00       0.02        6.0
# 10    15       45            1.00       0.00        6.0
# 11    20       30            1.50       0.08        5.0
# 12    20       35            1.25       0.02        5.0

# %%
df_embeddings = pd.read_csv("./clique_rnd_cnfs_embeddings.csv")
df_embeddings = df_embeddings.drop("Unnamed: 0", axis=1)
df_embeddings
# Out:
#     num_variables  num_clauses  var_clause_rel  max_chain_length  num_qubits  \
# 0              10           10            1.00                 3          60
# 1              10           15            0.67                 4          94
# 2              10           20            0.50                 4         114
# 3              10           25            0.40                 5         168
# 4              15           15            1.00                 4         114
# 5              15           20            0.75                 5         168
# 6              15           25            0.60                 5         192
# 7              15           30            0.50                 6         260
# 8              15           35            0.43                 6         290
# 9              15           40            0.38                 7         375
# 10             15           45            0.33                 7         408
# 11             20           30            0.67                 6         290
# 12             20           35            0.57                 7         375
#
#     variance
# 0   0.000000
# 1   0.190000
# 2   0.165517
# 3   0.164706
# 4   0.165517
# 5   0.164706
# 6   0.164103
# 7   0.176768
# 8   0.163265
# 9   0.151515
# 10  0.162712
# 11  0.163265
# 12  0.151515

# %%
merged_data = pd.merge(
    df_chain_strengths, 
    df_embeddings,  
    how='left', 
    left_on=['vars','clauses'], 
    right_on = ['num_variables','num_clauses'])
merged_data = merged_data.drop(['num_variables', 'num_clauses'],axis=1)
merged_data
# Out:
#     vars  clauses  chain_strength  precision  max_coeff  var_clause_rel  \
# 0     10       10            1.50       0.51        4.0            1.00
# 1     10       15            1.75       0.21        4.0            0.67
# 2     10       20            1.75       0.21        4.0            0.50
# 3     10       25            1.75       0.07        4.0            0.40
# 4     15       15            1.75       0.35        4.0            1.00
# 5     15       20            2.00       0.17        4.0            0.75
# 6     15       25            1.75       0.10        4.0            0.60
# 7     15       30            1.50       0.06        4.0            0.50
# 8     15       35            2.00       0.02        6.0            0.43
# 9     15       40            2.00       0.02        6.0            0.38
# 10    15       45            1.00       0.00        6.0            0.33
# 11    20       30            1.50       0.08        5.0            0.67
# 12    20       35            1.25       0.02        5.0            0.57
#
#     max_chain_length  num_qubits  variance
# 0                  3          60  0.000000
# 1                  4          94  0.190000
# 2                  4         114  0.165517
# 3                  5         168  0.164706
# 4                  4         114  0.165517
# 5                  5         168  0.164706
# 6                  5         192  0.164103
# 7                  6         260  0.176768
# 8                  6         290  0.163265
# 9                  7         375  0.151515
# 10                 7         408  0.162712
# 11                 6         290  0.163265
# 12                 7         375  0.151515

# %%
df_ratio_sat = pd.read_csv("./random_cnfs.csv")
df_ratio_sat = df_ratio_sat.drop(['Unnamed: 0'], axis=1)
merged_data2 = pd.merge(
    merged_data, 
    df_ratio_sat,  
    how='left', 
    left_on=['vars','clauses'], 
    right_on = ['variables','clauses'])

merged_data2 = merged_data2.drop(['variables'], axis=1)

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
ax = sns.heatmap(merged_data2.corr(), cbar=True, annot=True)

# %%
merged_data2.to_csv("./clique_final_results.csv")
